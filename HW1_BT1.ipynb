# %%
#B1
n = int(input())
print(n*2)

# %%
#B2
a,b = map(float, input().split())
r = b/2
print(a*b - r*r*3.14)

# %%
#B3
c = input()
if ord(c) < 97:
    print(chr(ord(c)+32))
else:
    print(chr(ord(c)-32))

# %%
#B4
c = input()
if ord(c) > 64 and ord(c) < 91 or ord(c) > 96 and ord(c) < 123:
    print(c + " là kí tự alphabet")
else:
    print(c + " không phải là kí tự alphabet")

# %%
#B5
c = input()
if ord(c) == 65:
    print("đặc biệt")
else:
    print(char(ord(c+31)))

# %%
#B6
a,b,c = map(int, input().split())
p = (a + b + c) / 2
if a + b > c and a + c > b and b + c > a:
    print(round((p*(p-a)*(p-b)*(p-c))**(0.5),1)) 
else:
    print("3 cạnh trên không tạo thành tam giác")

# %%
#B7
s = input()
print(s[4], s[8])

# %%
#B8
Hoten = input()
thangtruoc = int(input())
thangnay = int(input())
print(f'Ho va ten: {Hoten}')
tiendien = 0
sodien = thangnay - thangtruoc
for i in range(1, sodien + 1):
    if i <=50:
        tiendien += 1984
    elif i <= 100: 
        tiendien += 2050
    elif i <= 200:
        tiendien += 2380
    elif i <= 300:
        tiendien += 2998
    elif i <= 400:
        tiendien += 3350
    else:
        tiendien += 3460
print(f'Ho va ten {Hoten}')
print(f'Tien phai tra la: {tiendien * 1.08}')
